# %%
# %matplotlib inline
import scipy as sp
import numpy as np
from skimage.transform import rescale
from skimage.morphology import disk 
from skimage.data import camera
import skimage
from skimage.filters.rank import median

im = camera()
# Downsample the image by a factor of 4
im = rescale(im, .4)

# %%
import matplotlib.pyplot as plt
plt.imshow(im, cmap=plt.cm.binary)

# %%
from sklearn.feature_extraction import img_to_graph
graph = img_to_graph(im)
graph.data = np.exp(-graph.data / graph.data.std())

# %%
from sklearn.cluster import spectral_clustering
labels = spectral_clustering(graph, n_clusters=2, eigen_solver='arpack')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-48c7da12f640> in <module>()
#       1 from sklearn.cluster import spectral_clustering
# ----> 2 labels = spectral_clustering(graph, n_clusters=2, eigen_solver='arpack')
#
# /Users/aaronkravitz/anaconda/lib/python2.7/site-packages/sklearn/cluster/spectral.pyc in spectral_clustering(affinity, n_clusters, n_components, eigen_solver, random_state, n_init, eigen_tol, assign_labels)
#     253                               eigen_solver=eigen_solver,
#     254                               random_state=random_state,
# --> 255                               eigen_tol=eigen_tol, drop_first=False)
#     256
#     257     if assign_labels == 'kmeans':
#
# /Users/aaronkravitz/anaconda/lib/python2.7/site-packages/sklearn/manifold/spectral_embedding_.pyc in spectral_embedding(adjacency, n_components, eigen_solver, random_state, eigen_tol, norm_laplacian, drop_first, mode)
#     258             lambdas, diffusion_map = eigsh(-laplacian, k=n_components,
#     259                                            sigma=1.0, which='LM',
# --> 260                                            tol=eigen_tol)
#     261             embedding = diffusion_map.T[n_components::-1] * dd
#     262         except RuntimeError:
#
# /Users/aaronkravitz/anaconda/lib/python2.7/site-packages/scipy/sparse/linalg/eigen/arpack/arpack.pyc in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1585
#    1586     while not params.converged:
# -> 1587         params.iterate()
#    1588
#    1589     return params.extract(return_eigenvectors)
#
# /Users/aaronkravitz/anaconda/lib/python2.7/site-packages/scipy/sparse/linalg/eigen/arpack/arpack.pyc in iterate(self)
#     552             else:
#     553                 Bxslice = slice(self.ipntr[2] - 1, self.ipntr[2] - 1 + self.n)
# --> 554                 self.workd[yslice] = self.OPa(self.workd[Bxslice])
#     555         elif self.ido == 2:
#     556             self.workd[yslice] = self.B(self.workd[xslice])
#
# /Users/aaronkravitz/anaconda/lib/python2.7/site-packages/scipy/sparse/linalg/eigen/arpack/arpack.pyc in matvec(self, x)
#     913                     + 1j * self.M_lu.solve(np.imag(x).astype(self.dtype)))
#     914         else:
# --> 915             return self.M_lu.solve(x.astype(self.dtype))
#     916
#     917
#
# KeyboardInterrupt:

# %%
plt.imshow(labels.reshape(im.shape))
